# %%
# Install Libraries
# !pip install textblob
# !pip install tweepy
# !pip install pycountry
# !pip install wordcloud
# !pip install langdetect
# Out:
# Requirement already satisfied: textblob in c:\users\greeshma reddy\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\greeshma reddy\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: joblib in c:\users\greeshma reddy\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: click in c:\users\greeshma reddy\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: colorama in c:\users\greeshma reddy\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.5)
# Requirement already satisfied: tweepy in c:\users\greeshma reddy\anaconda3\lib\site-packages (4.14.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from tweepy) (2.28.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.11)
# Requirement already satisfied: pycountry in c:\users\greeshma reddy\anaconda3\lib\site-packages (22.3.5)
# Requirement already satisfied: setuptools in c:\users\greeshma reddy\anaconda3\lib\site-packages (from pycountry) (63.4.1)
# Requirement already satisfied: wordcloud in c:\users\greeshma reddy\anaconda3\lib\site-packages (1.9.1.1)
# Requirement already satisfied: pillow in c:\users\greeshma reddy\anaconda3\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\greeshma reddy\anaconda3\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\greeshma reddy\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: langdetect in c:\users\greeshma reddy\anaconda3\lib\site-packages (1.0.9)
# Requirement already satisfied: six in c:\users\greeshma reddy\anaconda3\lib\site-packages (from langdetect) (1.16.0)

# %%
# Import Libraries

from textblob import TextBlob
import sys
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import nltk
import pycountry
import re
import string
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from langdetect import detect
from nltk.stem import SnowballStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Greeshma
# [nltk_data]     Reddy\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# # Step 2: Authentication for Twitter API

# %%
# Authentication
consumerKey = "2CJbp8m7Rg26LtZEKAeVXWceG"
consumerSecret = "IbULWKlS0uvhLnMTcFkzvMjDfZUcBM6eVbdLYMUbNafhieX8Y6"
accessToken = "1119095264961126402-8QDK0FvTjGmV7w1hUtGsTyCyH77bNE"
accessTokenSecret = "unheMaBnZsHrcBt3mK1bE8Ib4wtE3tPtAwSA65Y0zWIK0"

auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth)

# %% [markdown]
# # Step 3: Getting Tweets With Keyword or Hashtag

# %%
#Sentiment Analysis
def percentage(part,whole):
    return 100 * float(part)/float(whole) 

keyword = input("Please enter keyword or hashtag to search: ")
noOfTweet = int(input ("Please enter how many tweets to analyze: "))

tweets = tweepy.Cursor(api.search_tweets, q=keyword).items(noOfTweet)
positive  = 0
negative = 0
neutral = 0
polarity = 0
tweet_list = []
neutral_list = []
negative_list = []
positive_list = []

for tweet in tweets:
    # print(tweet.text)
    tweet_list.append(tweet.text)
    analysis = TextBlob(tweet.text)
    score = SentimentIntensityAnalyzer().polarity_scores(tweet.text)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    polarity += analysis.sentiment.polarity
    
    if neg > pos:
        negative_list.append(tweet.text)
        negative += 1

    elif pos > neg:
        positive_list.append(tweet.text)
        positive += 1
    
    elif pos == neg:
        neutral_list.append(tweet.text)
        neutral += 1

positive = percentage(positive, noOfTweet)
negative = percentage(negative, noOfTweet)
neutral = percentage(neutral, noOfTweet)
polarity = percentage(polarity, noOfTweet)
positive = format(positive, '.1f')
negative = format(negative, '.1f')
neutral = format(neutral, '.1f')
# Out:
# Please enter keyword or hashtag to search: UCM
# Please enter how many tweets to analyze: 120

# %%
#Number of Tweets (Total, Positive, Negative, Neutral)
tweet_list = pd.DataFrame(tweet_list)
neutral_list = pd.DataFrame(neutral_list)
negative_list = pd.DataFrame(negative_list)
positive_list = pd.DataFrame(positive_list)
print("total number: ",len(tweet_list))
print("positive number: ",len(positive_list))
print("negative number: ", len(negative_list))
print("neutral number: ",len(neutral_list))
# Out:
# total number:  120
# positive number:  19
# negative number:  61
# neutral number:  40

# %%
tweet_list[0:20]
# Out:
#                                                     0
# 0   RT @peterjordan100: Geral falando bem de Guard...
# 1   RT @peterjordan100: Geral falando bem de Guard...
# 2   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 3   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 4   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 5   @GabyMeza8 Y hasta ahora, mi favorita del UCM ...
# 6   por mucho la mejor película que ha hecho Mariv...
# 7   Sintiéndome un poco calabaza espachurrada, esp...
# 8   RT @Multiverso_GK: Y así cierra, una de las me...
# 9   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 10  Porque los infuencers no pueden calificar #Gua...
# 11  🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠 El mejor prólogo del UCM https:/...
# 12  RT @MarvelLatin: Top 5 VILLANOS del UCM https:...
# 13  RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 14  RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 15  RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 16  Cómo voy a ponerme a pensar en otras historias...
# 17  RT @peterjordan100: Geral falando bem de Guard...
# 18  RT @MarvelLatin: Top 5 VILLANOS del UCM https:...
# 19  RT @Multiverso_GK: Y así cierra, una de las me...

# %%
#Creating PieCart

labels = ['Positive ['+str(positive)+'%]' , 'Neutral ['+str(neutral)+'%]','Negative ['+str(negative)+'%]']
sizes = [positive, neutral, negative]
colors = ['yellowgreen', 'blue','red']
patches, texts = plt.pie(sizes,colors=colors, startangle=90)
plt.style.use('default')
plt.legend(labels)
plt.title("Sentiment Analysis Result for keyword=  "+keyword+"" )
plt.axis('equal')
plt.show()

# %%
tweet_list.drop_duplicates(inplace = True)

# %% [markdown]
# # Extracting text values

# %%
tw_list = pd.DataFrame(tweet_list)
tw_list["text"] = tw_list[0]
tw_list
# Out:
#                                                      0  \
# 0    RT @peterjordan100: Geral falando bem de Guard...
# 2    RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 5    @GabyMeza8 Y hasta ahora, mi favorita del UCM ...
# 6    por mucho la mejor película que ha hecho Mariv...
# 7    Sintiéndome un poco calabaza espachurrada, esp...
# 8    RT @Multiverso_GK: Y así cierra, una de las me...
# 10   Porque los infuencers no pueden calificar #Gua...
# 11   🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠 El mejor prólogo del UCM https:/...
# 12   RT @MarvelLatin: Top 5 VILLANOS del UCM https:...
# 16   Cómo voy a ponerme a pensar en otras historias...
# 20   Por el #MayThe4thBeWithYou, #JamesGunn publicó...
# 21   @RonalGames117 La 2 me conmovió mil veces más ...
# 24   Guardianes de la galaxia 3 es una montaña rusa...
# 26   DC con James Gunn logrará darle la vuelta y su...
# 33   Increíblemente emotiva, desprende una sensació...
# 36   @lauramorata_ @toddedillard Sí, pero no es por...
# 41   ES LA MEJOR, UNA DE MIS FAVORITAS DEL UCM 👏🏼❤️...
# 76   RT @julieta_aramayo: @_NovelaGrafica Para mí s...
# 87   @J4viiKal Con Quantumania es cuando dije "hast...
# 90   @EnriiqueM_ Ay Dios… pa mi es la trilogía más ...
# 92   RT @MarvelLatin: Luego de analizarlo\n\n#Guard...
# 94   #GuardiansOfTheGalaxyVol3 es un PELICULÓN, me ...
# 95   RT @AndresEHernnde1: En Villa Clara hoy defien...
# 102  ¡Gracias! El lunes iniciaremos clases de esta ...
# 108  RT @lpuchg: @Raulsees @darioserranopue @nadaes...
# 113  @MarvelLatin Top 5 VILLANOS del UCM https://t....

# %%
#Cleaning Text (RT, Punctuation etc)

#Creating new dataframe and new features
tw_list = pd.DataFrame(tweet_list)
tw_list["text"] = tw_list[0]

#Removing RT, Punctuation etc
remove_rt = lambda x: re.sub('RT @\w+: '," ",x)
rt = lambda x: re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",x)
tw_list["text"] = tw_list.text.map(remove_rt).map(rt)
tw_list["text"] = tw_list.text.str.lower()
tw_list.head(10)
# Out:
#                                                     0  \
# 0   RT @peterjordan100: Geral falando bem de Guard...
# 2   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 5   @GabyMeza8 Y hasta ahora, mi favorita del UCM ...
# 6   por mucho la mejor película que ha hecho Mariv...
# 7   Sintiéndome un poco calabaza espachurrada, esp...
# 8   RT @Multiverso_GK: Y así cierra, una de las me...
# 10  Porque los infuencers no pueden calificar #Gua...
# 11  🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠 El mejor prólogo del UCM https:/...
# 12  RT @MarvelLatin: Top 5 VILLANOS del UCM https:...
# 16  Cómo voy a ponerme a pensar en otras historias...
#
#                                                  text
# 0    geral falando bem de guardi es da gal xia  ge...
# 2     en honor a star wars    por el  maythe4thbew...
# 5     y hasta ahora  mi favorita del ucm es guardi...
# 6   por mucho la mejor pel cula que ha hecho mariv...
# 7   sinti ndome un poco calabaza espachurrada  esp...
# 8    y as  cierra  una de las mejores trilog as de...
# 10  porque los infuencers no pueden calificar  gua...
# 11                         el mejor pr logo del ucm
# 12                           top 5 villanos del ucm
# 16  c mo voy a ponerme a pensar en otras historias...

# %%
#Calculating Negative, Positive, Neutral and Compound values

tw_list[['polarity', 'subjectivity']] = tw_list['text'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, row in tw_list['text'].iteritems():
    score = SentimentIntensityAnalyzer().polarity_scores(row)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    if neg > pos:
        tw_list.loc[index, 'sentiment'] = "negative"
    elif pos > neg:
        tw_list.loc[index, 'sentiment'] = "positive"
    else:
        tw_list.loc[index, 'sentiment'] = "neutral"
    tw_list.loc[index, 'neg'] = neg
    tw_list.loc[index, 'neu'] = neu
    tw_list.loc[index, 'pos'] = pos
    tw_list.loc[index, 'compound'] = comp

tw_list.head(10)
# Out:
#                                                     0  \
# 0   RT @peterjordan100: Geral falando bem de Guard...
# 2   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 5   @GabyMeza8 Y hasta ahora, mi favorita del UCM ...
# 6   por mucho la mejor película que ha hecho Mariv...
# 7   Sintiéndome un poco calabaza espachurrada, esp...
# 8   RT @Multiverso_GK: Y así cierra, una de las me...
# 10  Porque los infuencers no pueden calificar #Gua...
# 11  🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠🫠 El mejor prólogo del UCM https:/...
# 12  RT @MarvelLatin: Top 5 VILLANOS del UCM https:...
# 16  Cómo voy a ponerme a pensar en otras historias...
#
#                                                  text  polarity  subjectivity  \
# 0    geral falando bem de guardi es da gal xia  ge...       0.0      0.000000
# 2     en honor a star wars    por el  maythe4thbew...       0.0      0.066667
# 5     y hasta ahora  mi favorita del ucm es guardi...       0.0      0.000000
# 6   por mucho la mejor pel cula que ha hecho mariv...       0.0      0.000000
# 7   sinti ndome un poco calabaza espachurrada  esp...       0.0      0.000000
# 8    y as  cierra  una de las mejores trilog as de...       0.0      0.000000
# 10  porque los infuencers no pueden calificar  gua...       0.5      0.500000
# 11                         el mejor pr logo del ucm         0.0      0.000000
# 12                           top 5 villanos del ucm         0.5      0.500000
# 16  c mo voy a ponerme a pensar en otras historias...       0.0      0.000000
#
#    sentiment    neg    neu    pos  compound
# 0    neutral  0.000  1.000  0.000    0.0000
# 2   negative  0.165  0.688  0.147   -0.1027
# 5    neutral  0.000  1.000  0.000    0.0000
# 6   positive  0.000  0.876  0.124    0.3400
# 7    neutral  0.000  1.000  0.000    0.0000
# 8    neutral  0.000  1.000  0.000    0.0000
# 10  negative  0.210  0.619  0.171   -0.2023
# 11   neutral  0.000  1.000  0.000    0.0000
# 12  positive  0.000  0.625  0.375    0.2023
# 16   neutral  0.000  1.000  0.000    0.0000

# %%
#Creating new data frames for all sentiments (positive, negative and neutral)

tw_list_negative = tw_list[tw_list["sentiment"]=="negative"]
tw_list_positive = tw_list[tw_list["sentiment"]=="positive"]
tw_list_neutral = tw_list[tw_list["sentiment"]=="neutral"]

# %%
#Function for count_values_in single columns

def count_values_in_column(data,feature):
    total=data.loc[:,feature].value_counts(dropna=False)
    percentage=round(data.loc[:,feature].value_counts(dropna=False,normalize=True)*100,2)
    return pd.concat([total,percentage],axis=1,keys=['Total','Percentage'])

# %%
#Count_values for sentiment
count_values_in_column(tw_list,"sentiment")
# Out:
#           Total  Percentage
# neutral      21       58.33
# negative     10       27.78
# positive      5       13.89

# %%
# create data for Pie Chart
pc = count_values_in_column(tw_list,"sentiment")
names= pc.index
size=pc["Percentage"]
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(size, labels=names, colors=['green','blue','red'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
#Function to Create Wordcloud

def create_wordcloud(text):
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color="white", width=600, height=400,               
                  max_words=300,
                  stopwords=stopwords,
                  repeat=True)
    wc.generate(str(text))
    
    plt.imshow(wc)
    plt.show()

# %%
#Creating wordcloud for all tweets
create_wordcloud(tw_list["text"].values)

# %%
#Creating wordcloud for positive sentiment
create_wordcloud(tw_list_positive["text"].values)

# %%
#Creating wordcloud for negative sentiment
create_wordcloud(tw_list_negative["text"].values)

# %%
#Creating wordcloud for neutral sentiment
create_wordcloud(tw_list_neutral["text"].values)
